# %% [markdown]
# bu projede,<web scrapingve açık veri setleri>metodunu kullanarak veri topladık.
# veri kümesi,<google forms>platformundan elde edilmiştir.

# %%
import pandas as pd

# %%
df = pd.read_csv('proje_verisi.csv.csv')
df.head()
# Out:
#                   Çocuklarda internet kullanım oranı
# 0             2021 yılı =%82,7      2024 yılı =%91,3
# 1  Erkek çocuklar =%92,2 internet kullanım oranı ...
# 2   Çocukların %97,4 düzenli internet kullanıyor
# 3  Çocukların %42,9 u hafta içi     %53,6 sı haft...
# 4  Çocukların en fazla yürüttükleri faaliyet sıra...
